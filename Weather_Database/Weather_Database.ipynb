# %%
# import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# import the requests library
import requests

# import the API key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# starting url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create a set of 2000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Get the nearest city using citipy
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Perfom API call using OpenWeatherMap

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If error, skip the city.
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | murdochville
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | provideniya
# Processing Record 7 of Set 1 | mahebourg
# Processing Record 8 of Set 1 | ilulissat
# Processing Record 9 of Set 1 | castro
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | hobyo
# Processing Record 12 of Set 1 | dali
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | riohacha
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | paamiut
# Processing Record 17 of Set 1 | vostok
# Processing Record 18 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | lavrentiya
# Processing Record 26 of Set 1 | sur
# Processing Record 27 of Set 1 | samarai
# Processing Record 28 of Set 1 | sao filipe
# Processing Record 29 of Set 1 | bandarbeyla
# Processing Record 30 of Set 1 | otradnoye
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | sao joao da barra
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | coulihaut
# City not found. Skipping...
# Processing Record 35 of Set 1 | dunedin
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | bonthe
# Processing Record 38 of Set 1 | cidreira
# Processing Record 39 of Set 1 | tashtagol
# Processing Record 40 of Set 1 | san patricio
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | nabire
# Processing Record 43 of Set 1 | litovko
# Processing Record 44 of Set 1 | drumheller
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | lethem
# Processing Record 47 of Set 1 | evensk
# Processing Record 48 of Set 1 | pombia
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | mingguang
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | baykit
# Processing Record 4 of Set 2 | parrita
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | banda aceh
# Processing Record 8 of Set 2 | hofn
# Processing Record 9 of Set 2 | patrocinio
# Processing Record 10 of Set 2 | lagoa
# Processing Record 11 of Set 2 | east london
# Processing Record 12 of Set 2 | tabuk
# Processing Record 13 of Set 2 | sal rei
# Processing Record 14 of Set 2 | tomatlan
# Processing Record 15 of Set 2 | joetsu
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | havoysund
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | salalah
# Processing Record 22 of Set 2 | asau
# Processing Record 23 of Set 2 | orlovskiy
# Processing Record 24 of Set 2 | bathsheba
# Processing Record 25 of Set 2 | okha
# Processing Record 26 of Set 2 | zalesovo
# Processing Record 27 of Set 2 | acarau
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | namatanai
# Processing Record 30 of Set 2 | bluff
# Processing Record 31 of Set 2 | upernavik
# Processing Record 32 of Set 2 | rio verde de mato grosso
# Processing Record 33 of Set 2 | belmonte
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 2 | hamilton
# Processing Record 37 of Set 2 | nexo
# Processing Record 38 of Set 2 | klaksvik
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | talnakh
# Processing Record 42 of Set 2 | moron
# Processing Record 43 of Set 2 | envira
# Processing Record 44 of Set 2 | tiksi
# Processing Record 45 of Set 2 | bridlington
# Processing Record 46 of Set 2 | kerchevskiy
# Processing Record 47 of Set 2 | micheweni
# Processing Record 48 of Set 2 | saskylakh
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | touros
# Processing Record 1 of Set 3 | chimbote
# Processing Record 2 of Set 3 | slave lake
# Processing Record 3 of Set 3 | longyearbyen
# Processing Record 4 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 3 | bengkulu
# Processing Record 6 of Set 3 | harrison
# Processing Record 7 of Set 3 | port alfred
# Processing Record 8 of Set 3 | hanstholm
# Processing Record 9 of Set 3 | abha
# Processing Record 10 of Set 3 | champasak
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | atar
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | fortuna
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | kirakira
# Processing Record 17 of Set 3 | hilo
# Processing Record 18 of Set 3 | nemuro
# Processing Record 19 of Set 3 | solwezi
# Processing Record 20 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 3 | necochea
# Processing Record 22 of Set 3 | guerrero negro
# Processing Record 23 of Set 3 | puerto ayora
# Processing Record 24 of Set 3 | burnie
# Processing Record 25 of Set 3 | port hedland
# Processing Record 26 of Set 3 | denpasar
# Processing Record 27 of Set 3 | gamba
# Processing Record 28 of Set 3 | kastamonu
# Processing Record 29 of Set 3 | khormuj
# City not found. Skipping...
# Processing Record 30 of Set 3 | port hardy
# Processing Record 31 of Set 3 | leningradskiy
# Processing Record 32 of Set 3 | sao felix do xingu
# Processing Record 33 of Set 3 | naze
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | viedma
# Processing Record 36 of Set 3 | yellowknife
# Processing Record 37 of Set 3 | jutai
# Processing Record 38 of Set 3 | castelldefels
# Processing Record 39 of Set 3 | srednekolymsk
# Processing Record 40 of Set 3 | sitka
# Processing Record 41 of Set 3 | erenhot
# Processing Record 42 of Set 3 | ulundi
# Processing Record 43 of Set 3 | parati
# Processing Record 44 of Set 3 | bambous virieux
# Processing Record 45 of Set 3 | roma
# Processing Record 46 of Set 3 | tosya
# Processing Record 47 of Set 3 | mount isa
# Processing Record 48 of Set 3 | zyryanovsk
# Processing Record 49 of Set 3 | casper
# Processing Record 50 of Set 3 | mareeba
# Processing Record 1 of Set 4 | dingle
# Processing Record 2 of Set 4 | niquero
# Processing Record 3 of Set 4 | khatanga
# Processing Record 4 of Set 4 | natal
# Processing Record 5 of Set 4 | shimanovsk
# Processing Record 6 of Set 4 | dhidhdhoo
# Processing Record 7 of Set 4 | kahului
# Processing Record 8 of Set 4 | nelson bay
# Processing Record 9 of Set 4 | karasuk
# Processing Record 10 of Set 4 | neryungri
# Processing Record 11 of Set 4 | laguna
# Processing Record 12 of Set 4 | pangnirtung
# Processing Record 13 of Set 4 | mizdah
# Processing Record 14 of Set 4 | zhob
# Processing Record 15 of Set 4 | constitucion
# Processing Record 16 of Set 4 | cabedelo
# Processing Record 17 of Set 4 | praya
# Processing Record 18 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 4 | nanortalik
# Processing Record 21 of Set 4 | kapoeta
# Processing Record 22 of Set 4 | lalmohan
# Processing Record 23 of Set 4 | pemberton
# Processing Record 24 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 4 | kitgum
# Processing Record 26 of Set 4 | sydney
# Processing Record 27 of Set 4 | luderitz
# Processing Record 28 of Set 4 | karangampel
# Processing Record 29 of Set 4 | sambava
# Processing Record 30 of Set 4 | salta
# Processing Record 31 of Set 4 | naryan-mar
# Processing Record 32 of Set 4 | algiers
# Processing Record 33 of Set 4 | korla
# Processing Record 34 of Set 4 | maniitsoq
# Processing Record 35 of Set 4 | ipixuna
# Processing Record 36 of Set 4 | souillac
# Processing Record 37 of Set 4 | port lincoln
# Processing Record 38 of Set 4 | ulaangom
# Processing Record 39 of Set 4 | zhelyabovka
# Processing Record 40 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 4 | babstovo
# Processing Record 42 of Set 4 | riverton
# Processing Record 43 of Set 4 | te anau
# Processing Record 44 of Set 4 | ngorongoro
# Processing Record 45 of Set 4 | vondrozo
# Processing Record 46 of Set 4 | pacific grove
# Processing Record 47 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 4 | uwayl
# City not found. Skipping...
# Processing Record 50 of Set 4 | isangel
# Processing Record 1 of Set 5 | vila velha
# Processing Record 2 of Set 5 | cap malheureux
# Processing Record 3 of Set 5 | chuy
# Processing Record 4 of Set 5 | cabo san lucas
# Processing Record 5 of Set 5 | tasiilaq
# Processing Record 6 of Set 5 | pemangkat
# Processing Record 7 of Set 5 | bindura
# Processing Record 8 of Set 5 | puerto leguizamo
# Processing Record 9 of Set 5 | faanui
# Processing Record 10 of Set 5 | pekan
# Processing Record 11 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 5 | marienburg
# Processing Record 13 of Set 5 | port-gentil
# Processing Record 14 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 15 of Set 5 | quzhou
# Processing Record 16 of Set 5 | leh
# Processing Record 17 of Set 5 | lalibela
# Processing Record 18 of Set 5 | esperance
# Processing Record 19 of Set 5 | santa maria
# Processing Record 20 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 5 | grao mogol
# Processing Record 22 of Set 5 | iqaluit
# Processing Record 23 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 5 | seoul
# Processing Record 25 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 5 | acapulco
# Processing Record 27 of Set 5 | newport
# Processing Record 28 of Set 5 | lazaro cardenas
# Processing Record 29 of Set 5 | pevek
# Processing Record 30 of Set 5 | kabo
# Processing Record 31 of Set 5 | zhuanghe
# Processing Record 32 of Set 5 | san quintin
# Processing Record 33 of Set 5 | loralai
# Processing Record 34 of Set 5 | hovd
# Processing Record 35 of Set 5 | mirante do paranapanema
# Processing Record 36 of Set 5 | aklavik
# Processing Record 37 of Set 5 | lysyye gory
# Processing Record 38 of Set 5 | geraldton
# Processing Record 39 of Set 5 | victoria
# Processing Record 40 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 5 | mahbubabad
# Processing Record 42 of Set 5 | fethiye
# Processing Record 43 of Set 5 | yanam
# Processing Record 44 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 5 | namibe
# Processing Record 46 of Set 5 | la paz
# Processing Record 47 of Set 5 | vestmannaeyjar
# Processing Record 48 of Set 5 | andenes
# Processing Record 49 of Set 5 | chiredzi
# Processing Record 50 of Set 5 | bouar
# Processing Record 1 of Set 6 | lodwar
# Processing Record 2 of Set 6 | road town
# Processing Record 3 of Set 6 | lata
# Processing Record 4 of Set 6 | mushie
# Processing Record 5 of Set 6 | kieta
# Processing Record 6 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 6 | clyde river
# Processing Record 8 of Set 6 | daru
# Processing Record 9 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 10 of Set 6 | ponta do sol
# Processing Record 11 of Set 6 | mao
# Processing Record 12 of Set 6 | san policarpo
# Processing Record 13 of Set 6 | ornskoldsvik
# Processing Record 14 of Set 6 | merauke
# Processing Record 15 of Set 6 | alice springs
# Processing Record 16 of Set 6 | husavik
# Processing Record 17 of Set 6 | upington
# Processing Record 18 of Set 6 | anadyr
# Processing Record 19 of Set 6 | kerteh
# City not found. Skipping...
# Processing Record 20 of Set 6 | russell
# Processing Record 21 of Set 6 | biak
# Processing Record 22 of Set 6 | teguise
# Processing Record 23 of Set 6 | kavieng
# Processing Record 24 of Set 6 | mayo
# Processing Record 25 of Set 6 | henties bay
# Processing Record 26 of Set 6 | port macquarie
# Processing Record 27 of Set 6 | maturin
# Processing Record 28 of Set 6 | vila franca do campo
# Processing Record 29 of Set 6 | ekhabi
# Processing Record 30 of Set 6 | maryville
# Processing Record 31 of Set 6 | colares
# Processing Record 32 of Set 6 | tunduru
# City not found. Skipping...
# Processing Record 33 of Set 6 | arraial do cabo
# Processing Record 34 of Set 6 | abu samrah
# Processing Record 35 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 6 | flinders
# Processing Record 37 of Set 6 | nuuk
# Processing Record 38 of Set 6 | port-cartier
# Processing Record 39 of Set 6 | whitehorse
# Processing Record 40 of Set 6 | kaitangata
# Processing Record 41 of Set 6 | kavaratti
# Processing Record 42 of Set 6 | nueva helvecia
# Processing Record 43 of Set 6 | la ronge
# Processing Record 44 of Set 6 | thompson
# Processing Record 45 of Set 6 | mount pleasant
# Processing Record 46 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 6 | urengoy
# Processing Record 48 of Set 6 | mount gambier
# Processing Record 49 of Set 6 | olafsvik
# Processing Record 50 of Set 6 | zyryanka
# Processing Record 1 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 2 of Set 7 | tautira
# Processing Record 3 of Set 7 | aykhal
# Processing Record 4 of Set 7 | awjilah
# Processing Record 5 of Set 7 | batticaloa
# Processing Record 6 of Set 7 | neiafu
# Processing Record 7 of Set 7 | mitla
# Processing Record 8 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 7 | beyneu
# Processing Record 10 of Set 7 | adrar
# Processing Record 11 of Set 7 | berdigestyakh
# Processing Record 12 of Set 7 | saint-augustin
# Processing Record 13 of Set 7 | tsumeb
# Processing Record 14 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 15 of Set 7 | hasaki
# Processing Record 16 of Set 7 | zolotkovo
# Processing Record 17 of Set 7 | bilma
# Processing Record 18 of Set 7 | pontes e lacerda
# Processing Record 19 of Set 7 | russkaya polyana
# Processing Record 20 of Set 7 | alta floresta
# Processing Record 21 of Set 7 | west bay
# Processing Record 22 of Set 7 | ostrovnoy
# Processing Record 23 of Set 7 | jyvaskyla
# Processing Record 24 of Set 7 | bafq
# Processing Record 25 of Set 7 | abapo
# Processing Record 26 of Set 7 | mul
# Processing Record 27 of Set 7 | bosobolo
# Processing Record 28 of Set 7 | benito juarez
# Processing Record 29 of Set 7 | eboli
# Processing Record 30 of Set 7 | pangai
# Processing Record 31 of Set 7 | haimen
# Processing Record 32 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 7 | port blair
# Processing Record 34 of Set 7 | north bend
# Processing Record 35 of Set 7 | znamenskoye
# Processing Record 36 of Set 7 | atambua
# Processing Record 37 of Set 7 | safaga
# Processing Record 38 of Set 7 | butterworth
# Processing Record 39 of Set 7 | hervey bay
# Processing Record 40 of Set 7 | iquique
# Processing Record 41 of Set 7 | turukhansk
# Processing Record 42 of Set 7 | bafoulabe
# Processing Record 43 of Set 7 | never
# Processing Record 44 of Set 7 | sibiti
# Processing Record 45 of Set 7 | elko
# Processing Record 46 of Set 7 | la baule-escoublac
# Processing Record 47 of Set 7 | faya
# Processing Record 48 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 7 | severo-kurilsk
# Processing Record 50 of Set 7 | telimele
# Processing Record 1 of Set 8 | bilibino
# Processing Record 2 of Set 8 | aracruz
# Processing Record 3 of Set 8 | okhotsk
# Processing Record 4 of Set 8 | kodinsk
# Processing Record 5 of Set 8 | torbay
# Processing Record 6 of Set 8 | mattru
# Processing Record 7 of Set 8 | veraval
# Processing Record 8 of Set 8 | abay
# Processing Record 9 of Set 8 | grand haven
# Processing Record 10 of Set 8 | kyra
# Processing Record 11 of Set 8 | okitipupa
# Processing Record 12 of Set 8 | praia da vitoria
# Processing Record 13 of Set 8 | havre-saint-pierre
# Processing Record 14 of Set 8 | kudahuvadhoo
# Processing Record 15 of Set 8 | vao
# Processing Record 16 of Set 8 | athabasca
# Processing Record 17 of Set 8 | saint anthony
# Processing Record 18 of Set 8 | jiuquan
# Processing Record 19 of Set 8 | meulaboh
# Processing Record 20 of Set 8 | vallenar
# Processing Record 21 of Set 8 | paredon
# Processing Record 22 of Set 8 | phan thiet
# Processing Record 23 of Set 8 | tezu
# Processing Record 24 of Set 8 | garissa
# Processing Record 25 of Set 8 | cherskiy
# Processing Record 26 of Set 8 | nuevitas
# Processing Record 27 of Set 8 | shipitsyno
# Processing Record 28 of Set 8 | katsuura
# Processing Record 29 of Set 8 | itarema
# Processing Record 30 of Set 8 | odienne
# Processing Record 31 of Set 8 | abu dhabi
# Processing Record 32 of Set 8 | shimizu
# Processing Record 33 of Set 8 | krasyliv
# Processing Record 34 of Set 8 | providencia
# Processing Record 35 of Set 8 | melo
# Processing Record 36 of Set 8 | sayat
# Processing Record 37 of Set 8 | pokhara
# Processing Record 38 of Set 8 | chulym
# Processing Record 39 of Set 8 | kuantan
# Processing Record 40 of Set 8 | aginskoye
# Processing Record 41 of Set 8 | alyangula
# Processing Record 42 of Set 8 | potam
# Processing Record 43 of Set 8 | juneau
# Processing Record 44 of Set 8 | vanimo
# Processing Record 45 of Set 8 | nizhniy tsasuchey
# Processing Record 46 of Set 8 | palaiokhora
# City not found. Skipping...
# Processing Record 47 of Set 8 | benidorm
# Processing Record 48 of Set 8 | pingshan
# Processing Record 49 of Set 8 | asyut
# Processing Record 50 of Set 8 | launceston
# Processing Record 1 of Set 9 | wajir
# Processing Record 2 of Set 9 | kerema
# Processing Record 3 of Set 9 | araguaina
# Processing Record 4 of Set 9 | kuba-taba
# Processing Record 5 of Set 9 | poyarkovo
# Processing Record 6 of Set 9 | marsh harbour
# Processing Record 7 of Set 9 | dourbali
# Processing Record 8 of Set 9 | liverpool
# Processing Record 9 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 9 | noyon
# Processing Record 11 of Set 9 | volot
# Processing Record 12 of Set 9 | kodiak
# Processing Record 13 of Set 9 | parras
# City not found. Skipping...
# Processing Record 14 of Set 9 | oyama
# Processing Record 15 of Set 9 | ambon
# Processing Record 16 of Set 9 | aqtobe
# Processing Record 17 of Set 9 | heilbron
# Processing Record 18 of Set 9 | ierapetra
# Processing Record 19 of Set 9 | cartagena
# Processing Record 20 of Set 9 | pokaran
# Processing Record 21 of Set 9 | alofi
# Processing Record 22 of Set 9 | killybegs
# Processing Record 23 of Set 9 | camocim
# Processing Record 24 of Set 9 | trairi
# Processing Record 25 of Set 9 | saint george
# Processing Record 26 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 9 | westport
# Processing Record 28 of Set 9 | altay
# Processing Record 29 of Set 9 | flin flon
# Processing Record 30 of Set 9 | sol-iletsk
# Processing Record 31 of Set 9 | chapais
# Processing Record 32 of Set 9 | mulege
# Processing Record 33 of Set 9 | baiyin
# Processing Record 34 of Set 9 | yanchukan
# City not found. Skipping...
# Processing Record 35 of Set 9 | amambai
# Processing Record 36 of Set 9 | takoradi
# Processing Record 37 of Set 9 | lompoc
# Processing Record 38 of Set 9 | mackenzie
# Processing Record 39 of Set 9 | kloulklubed
# Processing Record 40 of Set 9 | mana
# Processing Record 41 of Set 9 | guia de isora
# Processing Record 42 of Set 9 | gayeri
# Processing Record 43 of Set 9 | alekseyevsk
# Processing Record 44 of Set 9 | riyadh
# Processing Record 45 of Set 9 | chenzhou
# Processing Record 46 of Set 9 | boa vista
# Processing Record 47 of Set 9 | uk
# City not found. Skipping...
# Processing Record 48 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 9 | warkworth
# Processing Record 50 of Set 9 | waddan
# Processing Record 1 of Set 10 | mancheral
# Processing Record 2 of Set 10 | lake city
# Processing Record 3 of Set 10 | tanout
# Processing Record 4 of Set 10 | bafra
# Processing Record 5 of Set 10 | huarmey
# Processing Record 6 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 10 | malakal
# Processing Record 8 of Set 10 | bridgewater
# Processing Record 9 of Set 10 | banjarmasin
# Processing Record 10 of Set 10 | areia branca
# Processing Record 11 of Set 10 | usinsk
# Processing Record 12 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 13 of Set 10 | xichang
# Processing Record 14 of Set 10 | qaqortoq
# Processing Record 15 of Set 10 | buchanan
# Processing Record 16 of Set 10 | algeciras
# Processing Record 17 of Set 10 | kungurtug
# Processing Record 18 of Set 10 | homa bay
# Processing Record 19 of Set 10 | hualmay
# Processing Record 20 of Set 10 | winnemucca
# Processing Record 21 of Set 10 | svetlaya
# Processing Record 22 of Set 10 | kralendijk
# Processing Record 23 of Set 10 | yarensk
# Processing Record 24 of Set 10 | york
# Processing Record 25 of Set 10 | tuatapere
# Processing Record 26 of Set 10 | kharp
# Processing Record 27 of Set 10 | bintulu
# Processing Record 28 of Set 10 | gushikawa
# Processing Record 29 of Set 10 | tainan
# Processing Record 30 of Set 10 | antalaha
# Processing Record 31 of Set 10 | asfi
# Processing Record 32 of Set 10 | norman wells
# Processing Record 33 of Set 10 | realeza
# Processing Record 34 of Set 10 | luba
# Processing Record 35 of Set 10 | nome
# Processing Record 36 of Set 10 | corn island
# Processing Record 37 of Set 10 | talaya
# Processing Record 38 of Set 10 | bonavista
# Processing Record 39 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 10 | marystown
# Processing Record 41 of Set 10 | ziro
# Processing Record 42 of Set 10 | yafran
# Processing Record 43 of Set 10 | tazovskiy
# Processing Record 44 of Set 10 | minab
# Processing Record 45 of Set 10 | cairns
# Processing Record 46 of Set 10 | mountain home
# Processing Record 47 of Set 10 | luebo
# Processing Record 48 of Set 10 | inhambane
# Processing Record 49 of Set 10 | cienaga de oro
# Processing Record 50 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 1 of Set 11 | tshela
# Processing Record 2 of Set 11 | datong
# Processing Record 3 of Set 11 | neuquen
# Processing Record 4 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 11 | sabha
# Processing Record 6 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 11 | gornopravdinsk
# Processing Record 8 of Set 11 | bocaranga
# City not found. Skipping...
# Processing Record 9 of Set 11 | brae
# Processing Record 10 of Set 11 | cankuzo
# Processing Record 11 of Set 11 | muros
# Processing Record 12 of Set 11 | codrington
# Processing Record 13 of Set 11 | pirovskoye
# Processing Record 14 of Set 11 | san andres
# Processing Record 15 of Set 11 | topchanchi
# Processing Record 16 of Set 11 | tongliao
# Processing Record 17 of Set 11 | kemijarvi
# Processing Record 18 of Set 11 | kailua
# Processing Record 19 of Set 11 | eureka
# Processing Record 20 of Set 11 | aswan
# Processing Record 21 of Set 11 | esso
# Processing Record 22 of Set 11 | kostino
# Processing Record 23 of Set 11 | winkler
# Processing Record 24 of Set 11 | kyabe
# Processing Record 25 of Set 11 | cherdyn
# Processing Record 26 of Set 11 | amalapuram
# Processing Record 27 of Set 11 | janauba
# Processing Record 28 of Set 11 | raudeberg
# Processing Record 29 of Set 11 | bronnoysund
# Processing Record 30 of Set 11 | mandera
# Processing Record 31 of Set 11 | ocampo
# Processing Record 32 of Set 11 | haapiti
# Processing Record 33 of Set 11 | byron bay
# Processing Record 34 of Set 11 | caravelas
# Processing Record 35 of Set 11 | jijiga
# Processing Record 36 of Set 11 | narsaq
# Processing Record 37 of Set 11 | ahipara
# Processing Record 38 of Set 11 | portland
# Processing Record 39 of Set 11 | maria aurora
# Processing Record 40 of Set 11 | solnechnyy
# Processing Record 41 of Set 11 | atikokan
# Processing Record 42 of Set 11 | aripuana
# Processing Record 43 of Set 11 | chiang khong
# Processing Record 44 of Set 11 | nicoya
# Processing Record 45 of Set 11 | bhawanipatna
# Processing Record 46 of Set 11 | coquimbo
# Processing Record 47 of Set 11 | umm kaddadah
# Processing Record 48 of Set 11 | iskateley
# Processing Record 49 of Set 11 | la tuque
# Processing Record 50 of Set 11 | quelimane
# Processing Record 1 of Set 12 | tingo maria
# Processing Record 2 of Set 12 | tambun
# Processing Record 3 of Set 12 | pilar do sul
# Processing Record 4 of Set 12 | thurso
# Processing Record 5 of Set 12 | san cristobal
# Processing Record 6 of Set 12 | etchojoa
# Processing Record 7 of Set 12 | padang
# Processing Record 8 of Set 12 | barra
# Processing Record 9 of Set 12 | matagami
# Processing Record 10 of Set 12 | northam
# Processing Record 11 of Set 12 | jaguey grande
# Processing Record 12 of Set 12 | ahuimanu
# Processing Record 13 of Set 12 | rayachoti
# Processing Record 14 of Set 12 | nambucca heads
# Processing Record 15 of Set 12 | agadir
# Processing Record 16 of Set 12 | itoman
# Processing Record 17 of Set 12 | coos bay
# Processing Record 18 of Set 12 | uong bi
# Processing Record 19 of Set 12 | llanes
# Processing Record 20 of Set 12 | natchitoches
# Processing Record 21 of Set 12 | rudbar
# Processing Record 22 of Set 12 | mujiayingzi
# Processing Record 23 of Set 12 | witrivier
# City not found. Skipping...
# Processing Record 24 of Set 12 | mindelo
# Processing Record 25 of Set 12 | goderich
# Processing Record 26 of Set 12 | fairbanks
# Processing Record 27 of Set 12 | dire dawa
# Processing Record 28 of Set 12 | huntingdon
# Processing Record 29 of Set 12 | raahe
# Processing Record 30 of Set 12 | chicama
# Processing Record 31 of Set 12 | mizque
# Processing Record 32 of Set 12 | lesnoy
# Processing Record 33 of Set 12 | gazni
# City not found. Skipping...
# Processing Record 34 of Set 12 | mezen
# Processing Record 35 of Set 12 | kalevala
# Processing Record 36 of Set 12 | gurun
# Processing Record 37 of Set 12 | high prairie
# Processing Record 38 of Set 12 | hambantota
# Processing Record 39 of Set 12 | misratah
# Processing Record 40 of Set 12 | pueblo
# Processing Record 41 of Set 12 | rocha
# Processing Record 42 of Set 12 | baboua
# City not found. Skipping...
# Processing Record 43 of Set 12 | labuhan
# Processing Record 44 of Set 12 | galle
# Processing Record 45 of Set 12 | beckley
# Processing Record 46 of Set 12 | kiunga
# Processing Record 47 of Set 12 | amapa
# Processing Record 48 of Set 12 | rawson
# Processing Record 49 of Set 12 | san jose
# Processing Record 50 of Set 12 | nyaunglebin
# Processing Record 1 of Set 13 | prince rupert
# Processing Record 2 of Set 13 | nago
# Processing Record 3 of Set 13 | buique
# Processing Record 4 of Set 13 | vila do maio
# Processing Record 5 of Set 13 | maryborough
# Processing Record 6 of Set 13 | sandwick
# Processing Record 7 of Set 13 | torgau
# Processing Record 8 of Set 13 | watertown
# Processing Record 9 of Set 13 | kitimat
# Processing Record 10 of Set 13 | camrose
# Processing Record 11 of Set 13 | la palma
# Processing Record 12 of Set 13 | kushima
# Processing Record 13 of Set 13 | anqiu
# Processing Record 14 of Set 13 | yuxia
# Processing Record 15 of Set 13 | berlevag
# Processing Record 16 of Set 13 | honiara
# Processing Record 17 of Set 13 | greenville
# Processing Record 18 of Set 13 | srandakan
# Processing Record 19 of Set 13 | komsomolskiy
# Processing Record 20 of Set 13 | hirado
# Processing Record 21 of Set 13 | sinnamary
# Processing Record 22 of Set 13 | saurimo
# Processing Record 23 of Set 13 | seidu
# Processing Record 24 of Set 13 | puerto carreno
# Processing Record 25 of Set 13 | mbekenyera
# Processing Record 26 of Set 13 | malanje
# Processing Record 27 of Set 13 | ostuni
# Processing Record 28 of Set 13 | pisco
# Processing Record 29 of Set 13 | mitsamiouli
# Processing Record 30 of Set 13 | anahuac
# Processing Record 31 of Set 13 | don sak
# Processing Record 32 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 13 | yaan
# Processing Record 34 of Set 13 | lamar
# Processing Record 35 of Set 13 | vardo
# Processing Record 36 of Set 13 | ancud
# Processing Record 37 of Set 13 | mahabad
# Processing Record 38 of Set 13 | gazojak
# Processing Record 39 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 40 of Set 13 | ixtapa
# Processing Record 41 of Set 13 | dukat
# Processing Record 42 of Set 13 | loandjili
# Processing Record 43 of Set 13 | xuddur
# Processing Record 44 of Set 13 | ketchenery
# City not found. Skipping...
# Processing Record 45 of Set 13 | kyzyl-suu
# Processing Record 46 of Set 13 | sistranda
# Processing Record 47 of Set 13 | jiangyin
# Processing Record 48 of Set 13 | tefe
# Processing Record 49 of Set 13 | carnot
# Processing Record 50 of Set 13 | colonelganj
# Processing Record 1 of Set 14 | karonga
# Processing Record 2 of Set 14 | soure
# Processing Record 3 of Set 14 | cam ranh
# Processing Record 4 of Set 14 | shizunai
# Processing Record 5 of Set 14 | tual
# Processing Record 6 of Set 14 | balfour
# Processing Record 7 of Set 14 | broken hill
# Processing Record 8 of Set 14 | fort saint james
# Processing Record 9 of Set 14 | igdir
# Processing Record 10 of Set 14 | kindu
# Processing Record 11 of Set 14 | toora-khem
# Processing Record 12 of Set 14 | peruibe
# Processing Record 13 of Set 14 | candelaria
# Processing Record 14 of Set 14 | bedum
# Processing Record 15 of Set 14 | moses lake
# Processing Record 16 of Set 14 | carinhanha
# Processing Record 17 of Set 14 | bagdarin
# Processing Record 18 of Set 14 | sola
# Processing Record 19 of Set 14 | larkollen
# Processing Record 20 of Set 14 | madera
# Processing Record 21 of Set 14 | tarsus
# Processing Record 22 of Set 14 | saldanha
# Processing Record 23 of Set 14 | broome
# Processing Record 24 of Set 14 | anchorage
# Processing Record 25 of Set 14 | puerto narino
# Processing Record 26 of Set 14 | basoko
# Processing Record 27 of Set 14 | ciudad del maiz
# Processing Record 28 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 29 of Set 14 | novoorsk
# Processing Record 30 of Set 14 | zhigansk
# Processing Record 31 of Set 14 | egvekinot
# Processing Record 32 of Set 14 | wenling
# Processing Record 33 of Set 14 | la reforma
# Processing Record 34 of Set 14 | champerico
# Processing Record 35 of Set 14 | coihaique
# Processing Record 36 of Set 14 | pochutla
# Processing Record 37 of Set 14 | de-kastri
# Processing Record 38 of Set 14 | high level
# Processing Record 39 of Set 14 | bonfim
# Processing Record 40 of Set 14 | rio grande
# Processing Record 41 of Set 14 | aloleng
# Processing Record 42 of Set 14 | ketchikan
# Processing Record 43 of Set 14 | sinjah
# City not found. Skipping...
# Processing Record 44 of Set 14 | chandbali
# Processing Record 45 of Set 14 | qasigiannguit
# Processing Record 46 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 14 | wajima
# Processing Record 48 of Set 14 | sunland park
# Processing Record 49 of Set 14 | santa isabel do rio negro
# Processing Record 50 of Set 14 | arlit
# Processing Record 1 of Set 15 | sao borja
# Processing Record 2 of Set 15 | brodokalmak
# Processing Record 3 of Set 15 | gasa
# Processing Record 4 of Set 15 | kupang
# Processing Record 5 of Set 15 | makat
# Processing Record 6 of Set 15 | skarnes
# Processing Record 7 of Set 15 | kijang
# Processing Record 8 of Set 15 | sarangani
# Processing Record 9 of Set 15 | pitimbu
# Processing Record 10 of Set 15 | walvis bay
# Processing Record 11 of Set 15 | kruisfontein
# Processing Record 12 of Set 15 | do gonbadan
# Processing Record 13 of Set 15 | clarence town
# Processing Record 14 of Set 15 | yueyang
# Processing Record 15 of Set 15 | pandan
# Processing Record 16 of Set 15 | kununurra
# Processing Record 17 of Set 15 | havelock
# Processing Record 18 of Set 15 | plouzane
# Processing Record 19 of Set 15 | menongue
# Processing Record 20 of Set 15 | hami
# Processing Record 21 of Set 15 | boguchany
# Processing Record 22 of Set 15 | varhaug
# Processing Record 23 of Set 15 | jiroft
# City not found. Skipping...
# Processing Record 24 of Set 15 | belyy yar
# Processing Record 25 of Set 15 | bairiki
# Processing Record 26 of Set 15 | youkounkoun
# Processing Record 27 of Set 15 | khanpur
# Processing Record 28 of Set 15 | kucevo
# Processing Record 29 of Set 15 | caranavi
# Processing Record 30 of Set 15 | mpongwe
# Processing Record 31 of Set 15 | minnedosa
# Processing Record 32 of Set 15 | nyeri
# Processing Record 33 of Set 15 | holme
# Processing Record 34 of Set 15 | andros town
# Processing Record 35 of Set 15 | quatre cocos
# Processing Record 36 of Set 15 | cabra
# Processing Record 37 of Set 15 | los llanos de aridane
# Processing Record 38 of Set 15 | wanning
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 681
